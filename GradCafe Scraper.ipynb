# %%
import pandas as pd 

data = pd.read_csv("gradcafe.csv") 
data.head()
# Out:
#                major  gre_quant   degree  season  decision  gre_verbal  \
# 0  Computer Science,      160.0  Masters    Fall  Accepted       158.0
# 1  Computer Science,        NaN      PhD    Fall  Accepted         NaN
# 2  Computer Science,        NaN      PhD    Fall  Accepted         NaN
# 3  Computer Science,        NaN  Masters    Fall  Accepted         NaN
# 4  Computer Science,      168.0  Masters  Spring    Others       159.0
#
#   date_of_result  term_year  undergrad_gpa  date_added  \
# 0     2019-08-14       2019            NaN  2019-08-23
# 1     2019-08-22       2019            NaN  2019-08-21
# 2     2019-04-16       2019            NaN  2019-08-17
# 3     2019-05-22       2019            NaN  2019-08-17
# 4     2019-08-12       2020            3.8  2019-08-11
#
#                   applicant_status  \
# 0  International without US degree
# 1  International without US degree
# 2                          Unknown
# 3                          Unknown
# ...
